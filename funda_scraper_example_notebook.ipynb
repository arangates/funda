# %% [markdown]
# <a href="https://colab.research.google.com/github/arangates/funda/blob/main/funda_scraper_example_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install funda-scraper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from funda_scraper import FundaScraper

scraper = FundaScraper(area="eindhoven", want_to="buy", find_past=False, n_pages=1)
scraper
# Out:
# FundaScraper(area=eindhoven, want_to=buy, n_pages=1, use_past_data=False)

# %%
df = scraper.run()
# Out:
# 2023-06-14 08:52:05,623 - INFO - *** Phase 1: Fetch all the available links from all pages ***  (scrape.py:107)
# INFO:funda_scraper:*** Phase 1: Fetch all the available links from all pages ***
# 100%|██████████| 2/2 [00:02<00:00,  1.34s/it]
# 2023-06-14 08:52:08,332 - INFO - *** Got all the urls. 15 houses found in 1 pages. *** (scrape.py:118)
# INFO:funda_scraper:*** Got all the urls. 15 houses found in 1 pages. ***
# 2023-06-14 08:52:08,337 - INFO - *** Phase 2: Start scraping results from individual links *** (scrape.py:183)
# INFO:funda_scraper:*** Phase 2: Start scraping results from individual links ***
#   0%|          | 0/15 [00:00<?, ?it/s]
# 2023-06-14 08:52:27,798 - INFO - *** All scraping done: 15 results *** (scrape.py:195)
# INFO:funda_scraper:*** All scraping done: 15 results ***
# 2023-06-14 08:52:27,806 - INFO - *** Cleaning data *** (scrape.py:229)
# INFO:funda_scraper:*** Cleaning data ***

# %%
df.head()
# Out:
#    house_id       city house_type    building_type   price  price_m2  room  \
# 0  42131180  eindhoven       huis  Resale property  425000    3663.8     4
# 1  42146242  eindhoven       huis  Resale property  495000    4230.8     5
# 2  42132260  eindhoven       huis  Resale property  499000    3261.4     6
# 3  42132412  eindhoven       huis  Resale property  850000    5000.0     7
# 4  42145206  eindhoven       huis  Resale property  369000    3208.7     6
#
#    bedroom  bathroom  living_area  ... has_balcony  has_garden   zip  \
# 0        3         1          116  ...           0           1  5627
# 1        4         1          117  ...           0           1  5658
# 2        4         1          153  ...           0           1  5653
# 3        4         1          170  ...           0           1  5644
# 4        4         1          115  ...           0           1  5622
#
#              address year_built  house_age  date_list    ym_list year_list  \
# ...

# %%
scraper.save_csv(df)
# Out:
# 2023-06-14 08:52:49,627 - INFO - *** File saved: ./data/houseprice_20230614_eindhoven_selling_15.csv. *** (scrape.py:217)
# INFO:funda_scraper:*** File saved: ./data/houseprice_20230614_eindhoven_selling_15.csv. ***

# %%
scraper.clean_df.head(1)
# Out:
#    house_id       city house_type    building_type   price  price_m2  room  \
# 0  42131180  eindhoven       huis  Resale property  425000    3663.8     4
#
#    bedroom  bathroom  living_area  ... has_balcony  has_garden   zip  \
# 0        3         1          116  ...           0           1  5627
#
#        address year_built  house_age  date_list    ym_list year_list  \
# 0  Tullelaan 2       1985         38 2023-06-09 2023-06-01      2023
#
#                                              descrip
# 0  \r\nNieuw in de  verkoop  bij Tim  de Rouw:  G...
#
# [1 rows x 21 columns]
# ...

# %%
scraper.raw_df.head(1)
# Out:
#                                                  url          price  \
# 0  https://www.funda.nl/en/huur/amsterdam/apparte...  € 2,400 p/mo.
#
#                    address                                            descrip  \
# 0  Marie Heinekenplein 102  \r\nVERY LUXURY, 3-ROOM  APARTMENT  OF 105  M2...
#
#   listed_since             zip_code    size  year living_area  \
# 0        Today  1072 MK Amsterdam\r  105 m²  1995      105 m²
#
#                     kind_of_house  ...  \
# 0  Upstairs apartment (apartment)  ...
#
#                                              parking neighborhood_name  \
# 0  \nRegistration with KvK\n\nYes\n\nAnnual meeti...                na
#
#                                            date_list            date_sold  \
# 0  € 2,400 per month (none service charges)\r\n  ...  \nResale property\n
#
#            term price_sold                                     last_ask_price  \
# ...

# %%
scraper.links
# Out:
# ['https://www.funda.nl/en/koop/eindhoven/huis-42131180-tullelaan-2/',
#  'https://www.funda.nl/en/koop/eindhoven/huis-42146242-waterlinie-125/',
#  'https://www.funda.nl/en/koop/eindhoven/huis-42132260-zuidewijn-38/',
#  'https://www.funda.nl/en/koop/eindhoven/huis-42132412-schweitzerlaan-48/',
#  'https://www.funda.nl/en/koop/eindhoven/huis-42145206-barrierweg-204/',
#  'https://www.funda.nl/en/koop/eindhoven/huis-42146654-zomereik-26/',
#  'https://www.funda.nl/en/koop/eindhoven/huis-42146038-chet-bakerlaan-6/',
#  'https://www.funda.nl/en/koop/eindhoven/huis-88598052-salvador-allendestraat-5/',
#  'https://www.funda.nl/en/koop/eindhoven/huis-42147852-kalverstraat-46/',
#  'https://www.funda.nl/en/koop/eindhoven/huis-42145013-generaal-de-gaullelaan-15/',
#  'https://www.funda.nl/en/koop/eindhoven/huis-42145061-vrijkensven-2/',
#  'https://www.funda.nl/en/koop/eindhoven/huis-42145288-planetenlaan-8/',
#  'https://www.funda.nl/en/koop/eindhoven/huis-42148044-serlioweg-18/',
# ...
